# %% [markdown]
# ## INTRODUCTION
#
# This dataset gives us a brief description about the california housing data.By analysing this california house dataset we will determine the approximate price for the houses.The main aim of this dataset is to predict the median house prices for california.This dataset consists of the following features are as follows:
#
# ### FEATURES:
#
# 1.longitude:A measure of distance a house is located horizontally that is from west to east,a higher value is further towards west.Statistically it comes under numerical data type, i.e.,Continuous data.
#
# 2.latitude:A measure of distance a house is located vertically that is towards north,a higher value is further towards north.Statistically it comes under numerical data type, i.e.,Continuous data
#
# 3.housing_median_age:It is Median age of a house.Statistically it is of quantitative datatype,i.e.,Continuous data.
#
# 4.total_rooms:Total number of rooms within a block.Statistically it is of quantitative data type,i.e.,discrete data.
#
# 5.total_bedrooms:Total number of bedrooms within a block.Statistically it is of quantitative data type,i.e.,discrete data.
#
# 6.population:Total number of people residing within a block.Statistically it is of quantitative data type,i.e.,discrete data.
#
# 7.households:Total number of households,a group of people residing within a homeunit.Statistically it is of quantitative data type,i.e.,discrete data.
#
# 8.median_income:Median income of households within a block of houses.(measured in tens of thousands of US Dollars).It comes under continuous data.
#
# 9.median_house_value:Median house value for households within a block(measured in US Dollars).It comes under continuous data.
#
# 10.Ocean_proximity:Location of the house with respect to ocean.Statistically it is of categorical data i.e.,it is of nominal data type.
#
#
# ####  Classification
#
# Continous = latitide , longitude , housing_median_age , median_income , median_house_value
#
# discrete = total_rooms , total_bedrooms , population , households
#
# nominal = ocean_proximity

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
data.shape
# Out:
# (20640, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ## 1. What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.

# %%
data['median_income'].mean()  # mean() is used to find the average of a column
# Out:
# 3.8706710029070246

# %%
data.hist(bins = 50 ,figsize=(15,15)) # Used to find the histogram of every columns in the data set
plt.show() # to print the histogram

# %% [markdown]
# ### Observations
#
# 1. outliers are present in housing_media_age and median_house_value
# 2. Right skew = total_rooms,total_bedrooms,population,households and median_income
# 3. assymetric = latitude and logitude

# %% [markdown]
# ## 2 Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.

# %%
plt.hist(data['housing_median_age'] , bins = 50) # to plot the histogram of column 'housing_median_age'
plt.xlabel("housing_median_age")  # to label the x axis
plt.ylabel("Frequencies") # to label the x axis
plt.show() # to print the histogram

# %%
housing_median_age_skew = 3*(data['housing_median_age'].mean()- data['housing_median_age'].median())/data['housing_median_age'].std()
housing_median_age_skew # we use the equation Skewed =3*(mean-median)/std() to find the skewness, mean(),median() and std() is used to find mean,median and standard deviation respectively.
# Out:
# -0.08593506390480511

# %% [markdown]
# ### Observations
#
#  a skewness value of -0.08 would indicate a slightly left-skewed distribution, not a perfectly symmetrical one.

# %% [markdown]
# ## 3. Show with the help of visualization, how median_income and median_house_values are related?

# %%
sns.scatterplot(x='median_income',y='median_house_value',data=data)  # scatterplot is used to define the relationship between 2 numericcal values
plt.show()

# %% [markdown]
# ### Observations
#
# From this we can find that the media_house_value is directly proportional to median_income. i.e  median_house_value increases as median_income increases

# %% [markdown]
# ## 4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

# %%
data[data['total_bedrooms'].isnull()] # isnull() is used to find null and NaN values
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                  47         1256             NaN
# 341      -122.17     37.75                  38          992             NaN
# 538      -122.28     37.78                  29         5154             NaN
# 563      -122.24     37.75                  45          891             NaN
# 696      -122.10     37.69                  41          746             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                  18         3620             NaN
# 20268    -119.18     34.19                  19         2393             NaN
# 20372    -118.88     34.17                  15         4260             NaN
# 20460    -118.75     34.29                  17         5512             NaN
# 20484    -118.72     34.28                  17         3051             NaN
#
#        population  households  median_income  median_house_value  \
# 290           570         218         4.3750              161900
# 341           732         259         1.6196               85100
# 538          3741        1273         2.5762              173400
# 563           384         146         4.9489              247100
# 696           387         161         3.9063              178400
# ...           ...         ...            ...                 ...
# 20267        3171         779         3.3409              220500
# 20268        1938         762         1.6953              167400
# 20372        1701         669         5.1033              410700
# 20460        2734         814         6.6073              258100
# 20484        1705         495         5.7376              218600
#
#       ocean_proximity
# 290          NEAR BAY
# 341          NEAR BAY
# 538          NEAR BAY
# 563          NEAR BAY
# 696          NEAR BAY
# ...               ...
# 20267      NEAR OCEAN
# 20268      NEAR OCEAN
# 20372       <1H OCEAN
# 20460       <1H OCEAN
# 20484       <1H OCEAN
#
# [207 rows x 10 columns]

# %%
new_data = data.dropna(subset = 'total_bedrooms') # dropna is used to remove Nan and null values from the dataset
new_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  median_house_value  \
# 0             322         126         8.3252              452600
# 1            2401        1138         8.3014              358500
# 2             496         177         7.2574              352100
# 3             558         219         5.6431              341300
# 4             565         259         3.8462              342200
# ...           ...         ...            ...                 ...
# 20635         845         330         1.5603               78100
# 20636         356         114         2.5568               77100
# 20637        1007         433         1.7000               92300
# 20638         741         349         1.8672               84700
# 20639        1387         530         2.3886               89400
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %% [markdown]
# ## 5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

# %%
data['total_bedrooms'].mean()
# Out:
# 537.8705525375618

# %%
data['total_bedrooms'] = data['total_bedrooms'].fillna(data['total_bedrooms'].mean()) 
data  #fillna() is used to fill the null values in the dataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  median_house_value  \
# 0             322         126         8.3252              452600
# 1            2401        1138         8.3014              358500
# 2             496         177         7.2574              352100
# 3             558         219         5.6431              341300
# 4             565         259         3.8462              342200
# ...           ...         ...            ...                 ...
# 20635         845         330         1.5603               78100
# 20636         356         114         2.5568               77100
# 20637        1007         433         1.7000               92300
# 20638         741         349         1.8672               84700
# 20639        1387         530         2.3886               89400
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %% [markdown]
# ## 6. Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.

# %% [markdown]
# Median can be found out by taking the middle element of the sorted data in ascending order/descending order
#
# if the length of data rows is odd then the middle element is the median
# if the length of data rows is even we need to calculate the average of the middle element and the succesor of middle element

# %%
def median_data(dframe,col):
    sorted_data = sorted(dframe[col].dropna())  #  dropna is used to remove Nan and null values from the dataset
    length = len(sorted_data) # len() is used to find the length of sorted_data
    if length%2==1:
        return sorted_data[length//2] #if the length of data rows is odd then the middle element is the median
    else:
        mid = length//2
        return (sorted_data[mid-1]+sorted_data[mid])/2 # if the length of data rows is even we need to calculate the average of the middle element and the succesor of middle element

# %%
check = input("Enter the column for median to be checked : ")  # for user input on which column to check
med = median_data(data , check) # to call the function
print(f"The median for {check} is {med}") # to print the median
# Out:
# Enter the column for median to be checked : latitude
# The median for latitude is 34.26

# %% [markdown]
# ## 7. Plot latitude versus longitude and explain your observations.

# %%
sns.scatterplot(x='latitude',y='longitude',data=data)  #  scatterplot is used to define the relationship between 2 numericcal values
plt.show()

# %% [markdown]
# ### Observation
#
# Here we can see that latitude increase as longitude decreases , therefore we can say that latitude is inversely proportional to longitude

# %% [markdown]
# ## 8. Create a data set for which the ocean_proximity is ‘Near ocean’.

# %%
near_ocean_data = data.loc[data['ocean_proximity']=='NEAR OCEAN'] # loc is used to filter label based data
near_ocean_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
#        population  households  median_income  median_house_value  \
# 1850         1259         436         3.7557              109400
# 1851         1298         478         1.9797               85800
# 1852         1343         479         2.4805               73200
# 1853         1947         647         2.5795               68400
# 1854         1645         640         1.6654               74600
# ...           ...         ...            ...                 ...
# 20380         450         173        10.1597              500001
# 20381         671         319         6.4001              321800
# 20423         578         291         5.4346              428600
# 20424        6187        2207         6.6122              357600
# 20425        2703         834         6.8075              325900
#
#       ocean_proximity
# 1850       NEAR OCEAN
# 1851       NEAR OCEAN
# 1852       NEAR OCEAN
# 1853       NEAR OCEAN
# 1854       NEAR OCEAN
# ...               ...
# 20380      NEAR OCEAN
# 20381      NEAR OCEAN
# 20423      NEAR OCEAN
# 20424      NEAR OCEAN
# 20425      NEAR OCEAN
#
# [2658 rows x 10 columns]

# %% [markdown]
# ## 9. Find the mean and median of the median income for the data set created in question 8.

# %%
ne_oc_me = near_ocean_data['median_income'].mean()  # mean function is used to find the mean of the data
print(f"The mean of the median income in the new data set created is {ne_oc_me}")
# Out:
# The mean of the median income in the new data set created is 4.005784800601957

# %%
ne_oc_med = near_ocean_data['median_income'].median() # median function is used to find the median of the data
print(f"The mean of the median income in the new data set created is {ne_oc_med}")
# Out:
# The mean of the median income in the new data set created is 3.64705

# %% [markdown]
# ## 10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.

# %%
conditions = [
    (data['total_bedrooms']<=10),
    (data['total_bedrooms']>=11) & (data['total_bedrooms']<=1000),
    (data['total_bedrooms']>1000)
] # the conditions for the new column
values = ['Small','Medium','Large'] # values for the respective conditions

data['total_bedroom_size']= np.select(conditions,values , default = 'Unknown') # select() is used to apply conditions and provide value to the new column
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  median_house_value  \
# 0             322         126         8.3252              452600
# 1            2401        1138         8.3014              358500
# 2             496         177         7.2574              352100
# 3             558         219         5.6431              341300
# 4             565         259         3.8462              342200
# ...           ...         ...            ...                 ...
# 20635         845         330         1.5603               78100
# 20636         356         114         2.5568               77100
# 20637        1007         433         1.7000               92300
# 20638         741         349         1.8672               84700
# 20639        1387         530         2.3886               89400
#
#       ocean_proximity total_bedroom_size
# 0            NEAR BAY             Medium
# 1            NEAR BAY              Large
# 2            NEAR BAY             Medium
# 3            NEAR BAY             Medium
# 4            NEAR BAY             Medium
# ...               ...                ...
# 20635          INLAND             Medium
# 20636          INLAND             Medium
# 20637          INLAND             Medium
# 20638          INLAND             Medium
# 20639          INLAND             Medium
#
# [20640 rows x 11 columns]
